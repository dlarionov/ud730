# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
  
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5235, 3084, 12, 6, 195, 2, 3136, 46, 59, 156]

# %%
print('data:', [reverse_dictionary[di] for di in data[70000:70100]])
# Out:
# data: ['that', 'focused', 'on', 'analyzing', 'how', 'societies', 'held', 'together', 'in', 'the', 'present', 'the', 'two', 'most', 'important', 'names', 'in', 'this', 'tradition', 'were', 'alfred', 'reginald', 'radcliffe', 'brown', 'and', 'UNK', 'malinowski', 'both', 'of', 'whom', 'released', 'seminal', 'works', 'in', 'one', 'nine', 'two', 'two', 'radcliffe', 'brown', 's', 'initial', 'fieldwork', 'in', 'the', 'andaman', 'islands', 'was', 'carried', 'out', 'in', 'the', 'old', 'style', 'but', 'after', 'reading', 'mile', 'durkheim', 'he', 'published', 'an', 'account', 'of', 'his', 'research', 'entitled', 'simply', 'the', 'andaman', 'islanders', 'which', 'drew', 'heavily', 'on', 'the', 'french', 'sociologist', 'over', 'time', 'he', 'developed', 'an', 'approach', 'known', 'as', 'structural', 'functionalism', 'which', 'focused', 'on', 'how', 'institutions', 'in', 'societies', 'worked', 'to', 'balance', 'out', 'or']

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2), (1, 4)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'of', 'as', 'originated', 'term']
#
# with num_skips = 1 and skip_window = 4:
#     batch: ['term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#     labels: ['abuse', 'term', 'as', 'of', 'first', 'working', 'used', 'the']

# %% [markdown]
# Train a skip-gram model.

# %%
random.sample(range(100), 16)
# Out:
# [18, 58, 24, 92, 2, 49, 63, 4, 6, 74, 41, 14, 96, 20, 43, 36]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(
        weights=softmax_weights, 
        biases=softmax_biases, 
        inputs=embed,
        labels=train_labels, 
        num_sampled=num_sampled, 
        num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()  
    average_loss = 0
    
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
            
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)  
    
    final_embeddings = normalized_embeddings.eval()
# Out:
# Average loss at step 0: 7.843522
# Nearest to by: sustenance, rested, lachaise, whispering, lineal, humble, bacon, deciding,
# Nearest to its: dead, jazz, pollutants, mexico, manichean, bastion, simulated, bashar,
# Nearest to other: rappers, magnet, practise, dictates, yasser, gibeon, strict, knicks,
# Nearest to he: esteem, popularize, heian, infested, materiel, attributed, confucianism, complained,
# Nearest to nine: spartacus, datagrams, ministerio, lleida, overthrew, estrada, bothnia, hermon,
# Nearest to over: soma, northerly, yucatan, endowed, cryo, larousse, slobodan, picks,
# Nearest to between: lad, apparently, aalen, seceded, convolutions, estonia, ibis, fanon,
# Nearest to of: automobile, ministry, tractate, quality, labonte, esr, vocally, semantically,
# Nearest to the: czarist, nuances, funeral, leni, avengers, scandals, puckett, yuga,
# Nearest to will: bottleneck, narrowing, crucified, vine, dov, finders, cellist, ctor,
# Nearest to five: moonraker, ellesmere, performer, cheltenham, vestry, wta, hymnal, transwomen,
# Nearest to when: interwiki, utrecht, ausw, vaulted, chun, je, hund, totalitarian,
# Nearest to new: sheds, tyrone, nikolaevich, coloane, mcgregor, rind, unmarked, exons,
# Nearest to such: transmutations, ally, democratisation, ilinden, vez, councillor, alive, perlman,
# Nearest to been: pelagianism, shutter, beyond, forerunners, begins, slough, consummated, sins,
# Nearest to but: antiquarian, michigan, kabyle, schmitz, infarction, upcoming, viceroys, tudor,
# Average loss at step 2000: 4.369347
# Average loss at step 4000: 3.859094
# Average loss at step 6000: 3.790056
# Average loss at step 8000: 3.680945
# Average loss at step 10000: 3.615906
# Nearest to by: was, valdivia, as, contraindicated, from, in, bacon, with,
# Nearest to its: their, the, his, wifi, richards, individuals, resistivity, imp,
# Nearest to other: magnet, supposition, yasser, capitol, ballroom, smell, beams, politically,
# Nearest to he: it, she, they, who, esteem, bloodline, presenter, devotions,
# Nearest to nine: eight, six, five, seven, three, zero, four, two,
# Nearest to over: slobodan, northerly, participle, cryo, rameau, picks, soma, seized,
# Nearest to between: with, on, bookstore, lad, induced, apparently, carthage, aalen,
# Nearest to of: in, finned, from, tractate, exilic, for, dostoevsky, joanna,
# Nearest to the: a, its, this, his, any, each, voting, unambiguously,
# Nearest to will: may, could, can, would, to, dov, composes, philippi,
# Nearest to five: eight, six, seven, nine, three, four, zero, two,
# Nearest to when: tamil, je, interwiki, brothers, serpento, could, litres, illnesses,
# Nearest to new: sheds, nikolaevich, breakout, rind, unmarked, apostle, salamis, mcgregor,
# Nearest to such: democratisation, danny, osh, gunn, consequent, homemade, well, andhra,
# Nearest to been: afc, shutter, antoninianus, consummated, distributist, already, paused, illicit,
# Nearest to but: and, are, bromide, or, percentage, michigan, antiquarian, is,
# Average loss at step 12000: 3.605502
# Average loss at step 14000: 3.576903
# Average loss at step 16000: 3.408320
# Average loss at step 18000: 3.458434
# Average loss at step 20000: 3.537861
# Nearest to by: valdivia, bacon, through, in, from, be, austronesian, was,
# Nearest to its: their, his, the, multifinder, individuals, this, magnetization, richards,
# Nearest to other: many, some, beams, different, jai, countries, monoxide, are,
# Nearest to he: it, she, they, who, there, presenter, which, later,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to over: slobodan, rameau, northerly, establishments, contain, about, optional, scorned,
# Nearest to between: with, vfl, against, convolutions, aalen, bookstore, carthage, bes,
# Nearest to of: for, airship, in, oo, tractate, gabab, softening, joanna,
# Nearest to the: their, its, this, any, his, reconstructionism, a, an,
# Nearest to will: could, would, may, can, to, should, must, might,
# Nearest to five: six, seven, three, four, eight, zero, nine, two,
# Nearest to when: if, that, je, dilation, serpento, but, while, as,
# Nearest to new: sheds, nikolaevich, coulter, apostle, shaft, kat, below, asiatic,
# Nearest to such: well, known, democratisation, andhra, consequent, many, laughter, these,
# Nearest to been: already, be, afc, was, were, distributist, shutter, had,
# Nearest to but: however, though, if, and, which, linebacker, that, could,
# Average loss at step 22000: 3.500450
# Average loss at step 24000: 3.490469
# Average loss at step 26000: 3.475137
# Average loss at step 28000: 3.477187
# Average loss at step 30000: 3.506758
# Nearest to by: valdivia, under, from, starches, were, in, contraindicated, during,
# Nearest to its: their, his, the, richards, multifinder, scattered, vigour, falun,
# Nearest to other: many, some, beams, tourist, capitol, steppe, several, corporal,
# Nearest to he: she, it, they, who, there, presenter, we, guilds,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to over: about, establishments, aeronautics, predynastic, seized, clooney, diaries, scorned,
# Nearest to between: with, against, on, in, into, vfl, aalen, convolutions,
# Nearest to of: in, for, and, from, elephant, interrogators, vx, guano,
# Nearest to the: their, its, his, moseley, some, any, this, a,
# Nearest to will: could, would, can, may, should, must, might, to,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to when: if, after, while, was, je, but, during, dilation,
# Nearest to new: sheds, nikolaevich, apostle, asiatic, coulter, nerve, ticket, pagan,
# Nearest to such: well, known, these, many, certain, infamous, misogyny, democratisation,
# Nearest to been: already, was, be, were, become, afc, previously, isthmus,
# Nearest to but: however, though, which, although, and, when, could, premiers,
# Average loss at step 32000: 3.498489
# Average loss at step 34000: 3.493100
# Average loss at step 36000: 3.457882
# Average loss at step 38000: 3.299558
# Average loss at step 40000: 3.424359
# Nearest to by: teutons, through, with, valdivia, was, bacon, is, as,
# Nearest to its: their, his, the, her, multifinder, friendliness, our, richards,
# Nearest to other: different, many, various, more, such, including, beams, stretched,
# Nearest to he: she, it, they, there, who, i, we, diaries,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to over: diaries, rameau, within, establishments, seized, about, stylization, winners,
# Nearest to between: with, within, against, in, vfl, into, backronym, insisted,
# Nearest to of: in, from, munk, waterfront, containing, oo, greet, joanna,
# Nearest to the: their, his, a, its, any, this, some, another,
# Nearest to will: can, would, could, may, must, should, might, to,
# Nearest to five: seven, six, four, three, eight, nine, two, zero,
# Nearest to when: if, while, after, dilation, was, during, before, swain,
# Nearest to new: single, nikolaevich, sheds, apostle, comprehensive, fac, asiatic, theron,
# Nearest to such: known, well, these, many, certain, some, other, including,
# Nearest to been: be, become, already, was, afc, previously, were, isthmus,
# Nearest to but: however, though, and, although, utilization, unless, which, when,
# Average loss at step 42000: 3.437954
# Average loss at step 44000: 3.453806
# Average loss at step 46000: 3.450807
# Average loss at step 48000: 3.363185
# Average loss at step 50000: 3.382545
# Nearest to by: under, through, with, bacon, was, reichstag, pros, valdivia,
# Nearest to its: their, his, the, her, our, scattered, multifinder, falun,
# Nearest to other: different, many, various, stretched, some, artificial, including, oxygen,
# Nearest to he: she, it, they, who, there, preprocessing, we, this,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to over: between, about, off, diaries, sf, amicus, rameau, stain,
# Nearest to between: with, into, over, within, against, convolutions, backronym, roughly,
# Nearest to of: in, and, unpredictable, for, tumultuous, stitches, from, joanna,
# Nearest to the: their, its, this, a, his, some, multifinder, any,
# Nearest to will: would, could, can, may, must, should, might, shall,
# Nearest to five: six, four, seven, eight, three, two, zero, nine,
# Nearest to when: while, if, after, during, dilation, but, before, where,
# Nearest to new: single, sheds, predate, theron, comprehensive, fac, counteracting, third,
# Nearest to such: well, known, many, these, certain, described, ginette, defined,
# Nearest to been: already, become, be, previously, were, isthmus, was, had,
# Nearest to but: however, though, although, while, when, and, there, remixed,
# Average loss at step 52000: 3.434282
# Average loss at step 54000: 3.430237
# Average loss at step 56000: 3.442803
# Average loss at step 58000: 3.397772
# Average loss at step 60000: 3.391849
# Nearest to by: bacon, valdivia, through, contraindicated, was, vall, repugnant, reichstag,
# Nearest to its: their, his, the, her, scattered, magnetization, tls, falun,
# Nearest to other: various, different, more, many, technological, oxygen, others, sutras,
# Nearest to he: she, it, they, who, there, then, encircled, dylan,
# Nearest to nine: eight, seven, six, four, five, three, one, zero,
# Nearest to over: between, through, into, about, within, around, radiometric, diaries,
# Nearest to between: with, in, over, within, into, following, against, backronym,
# Nearest to of: in, for, joanna, although, lalr, include, oo, like,
# Nearest to the: its, their, a, this, some, his, any, multifinder,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to when: if, after, while, during, before, was, although, though,
# Nearest to new: sheds, single, conference, nikolaevich, theron, counteracting, comprehensive, asiatic,
# Nearest to such: well, known, certain, these, many, described, some, large,
# Nearest to been: become, be, already, previously, was, isthmus, had, were,
# Nearest to but: however, and, though, although, than, which, when, melted,
# Average loss at step 62000: 3.238601
# Average loss at step 64000: 3.257008
# Average loss at step 66000: 3.406468
# Average loss at step 68000: 3.394461
# Average loss at step 70000: 3.364350
# Nearest to by: through, bacon, valdivia, vall, without, teutons, in, fox,
# Nearest to its: their, his, the, her, friendliness, multifinder, magnetization, our,
# Nearest to other: various, different, many, including, some, technological, initiatives, such,
# Nearest to he: she, it, they, who, there, ruth, dylan, we,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to over: within, about, seized, commited, between, around, radiometric, through,
# Nearest to between: with, within, against, into, over, bernini, backronym, among,
# Nearest to of: including, original, bowstring, joanna, in, for, kabir, oo,
# Nearest to the: their, its, any, a, this, these, each, some,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to five: four, six, eight, three, seven, nine, zero, two,
# Nearest to when: if, while, after, before, where, though, during, because,
# Nearest to new: single, sheds, theron, hydrofoil, separate, counteracting, nikolaevich, tojo,
# Nearest to such: these, known, well, certain, many, some, other, having,
# Nearest to been: become, be, already, was, isthmus, had, previously, were,
# Nearest to but: however, though, which, although, than, while, and, that,
# Average loss at step 72000: 3.377366
# Average loss at step 74000: 3.349110
# Average loss at step 76000: 3.318941
# Average loss at step 78000: 3.354259
# Average loss at step 80000: 3.379147
# Nearest to by: through, valdivia, bacon, recluse, temperament, under, from, debilitating,
# Nearest to its: their, his, her, multifinder, the, our, friendliness, falun,
# Nearest to other: various, western, including, many, different, others, stretched, zip,
# Nearest to he: she, it, they, there, who, officially, later, never,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to over: around, within, about, commited, amicus, between, through, cavan,
# Nearest to between: within, with, into, onto, over, following, among, backronym,
# Nearest to of: ses, including, in, entire, waterfront, vigesimal, joanna, ultrasonic,
# Nearest to the: this, their, a, its, his, each, your, moseley,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to five: four, eight, six, seven, three, nine, zero, two,
# Nearest to when: if, while, before, after, during, though, although, where,
# Nearest to new: single, theron, nikolaevich, ticket, conference, murdoch, counteracting, naive,
# Nearest to such: well, these, certain, known, many, including, mein, laughter,
# Nearest to been: become, be, already, was, had, being, previously, isthmus,
# Nearest to but: however, and, although, though, while, see, than, saw,
# Average loss at step 82000: 3.407960
# Average loss at step 84000: 3.409246
# Average loss at step 86000: 3.390907
# Average loss at step 88000: 3.352416
# Average loss at step 90000: 3.369014
# Nearest to by: through, scarborough, reichstag, under, recluse, bacon, during, valdivia,
# Nearest to its: their, his, her, the, our, magnetization, multifinder, friendliness,
# Nearest to other: various, different, technological, jetty, including, initiatives, western, religious,
# Nearest to he: she, it, they, there, who, officially, later, but,
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Nearest to over: within, amicus, between, around, about, off, through, aeronautics,
# Nearest to between: with, within, into, over, among, onto, following, against,
# Nearest to of: in, including, for, joanna, adema, oo, ultrasonic, vigesimal,
# Nearest to the: its, their, multifinder, this, his, a, our, concentrations,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to five: eight, seven, four, six, three, two, nine, zero,
# Nearest to when: if, while, before, after, though, where, until, during,
# Nearest to new: hydrofoil, theron, mummified, fac, different, philippine, organizing, ticket,
# Nearest to such: known, well, certain, these, many, defined, described, laughter,
# Nearest to been: become, be, already, was, being, previously, remained, isthmus,
# Nearest to but: however, and, although, though, while, harassed, he, see,
# Average loss at step 92000: 3.401914
# Average loss at step 94000: 3.255005
# Average loss at step 96000: 3.355013
# Average loss at step 98000: 3.249627
# Average loss at step 100000: 3.356699
# Nearest to by: valdivia, bacon, fiendish, without, through, under, when, during,
# Nearest to its: their, his, the, her, multifinder, friendliness, our, magnetization,
# Nearest to other: various, including, others, western, imaginary, technological, fungal, different,
# Nearest to he: she, it, they, there, who, we, never, watchman,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to over: around, amicus, within, between, cavan, through, off, commited,
# Nearest to between: with, into, within, over, among, following, onto, against,
# Nearest to of: including, palomino, and, in, original, joanna, paratime, whose,
# Nearest to the: their, its, his, your, this, any, her, my,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to five: four, six, eight, seven, three, two, zero, nine,
# Nearest to when: if, while, after, before, though, where, although, because,
# Nearest to new: separate, theron, single, ticket, different, counteracting, fac, organizing,
# Nearest to such: known, well, certain, these, many, including, defined, follows,
# Nearest to been: become, be, already, previously, remained, was, isthmus, blinded,
# Nearest to but: however, although, and, though, while, which, triage, than,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# TODO
